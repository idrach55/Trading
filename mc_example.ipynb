# %%
# %pylab inline

import mc
import pandas as pd
from importlib import reload

rcParams['figure.figsize'] = (12,8)
rcParams['axes.grid'] = True
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
reload(mc)
# Out:
# <module 'mc' from '/Users/isaacdrachman/Documents/GitHub/Gradient/mc.py'>

# %%
JD_params = {'S0': 100.0, 'r': 0.00, 'q': 0.0, 'sigma': 0.10, 'lambda': 0.01, 'j_sigma': 0.05, 'j_mu': 0.0}
GBM_params = {'S0': 100.0, 'r': 0.00, 'q': 0.00, 'sigma': 0.125}

jd = mc.GBMJD_gen(JD_params)
gbm = mc.GBM_gen(GBM_params)

# %%
option = mc.Option(100.0, None, 'PUT', 'E', {'num_paths': 200000, 'num_steps': 252, 'dt': 1/252})

# %%
plot(gbm.generate(1,252,1/252)[0], label='GBM process')
plot(jd.generate(1,252,1/252)[0], label='GBMJD process')
legend(loc='upper left')

# %%
option.delta(jd)
# Out:
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-240-f43ef2b8da2f> in <module>
# ----> 1 option.delta(jd)
#
# ~/Documents/GitHub/Gradient/mc.py in delta(self, gen, bump)
#     117
#     118     def delta(self, gen, bump=0.01):
# --> 119         value_S = self.value(gen)
#     120         value_Splus = self.value(gen.pertubate('S0',bump,shift='rel'))
#     121         value_Sminus = self.value(gen.pertubate('S0',-bump,shift='rel'))
#
# ~/Documents/GitHub/Gradient/mc.py in value(self, gen)
#     113         num_steps = self.val_params['num_steps']
#     114         dt = self.val_params['dt']
# --> 115         mean_value, error = MC(gen, num_paths, num_steps, dt, self.payoff)
#     116         return mean_value
#     117
#
# ~/Documents/GitHub/Gradient/mc.py in MC(gen, num_paths, num_steps, dt, payoff)
#      83         paths = gen(num_paths, num_steps, dt)
#      84     else:
# ...

# %%
option.delta(gbm)

# %%
option.value(gbm)

# %%
s1 = jd.generate(1,252,1/252)[0]

# %%
values, deltas = option.time_series(jd,s1)

# %%
import time

# %%
a = time.time()
option.value(mc.GBM_generator(100.0,0.0,0.0,0.10))
b = time.time()
print(b-a)
# Out:
# 3.9817919731140137

# %%
# Out:
# builtin_function_or_method
